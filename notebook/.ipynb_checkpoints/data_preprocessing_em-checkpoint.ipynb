# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data
data1 = pd.read_csv('../dataset/01_raw/2009_2020_crime_data.csv')
data2 = pd.read_csv('../dataset/01_raw/2021_2024_crime_data.csv')
# Out:
# /var/folders/5t/k32b1zys181cv4n2nz_7rq1c0000gp/T/ipykernel_86413/4240206472.py:3: DtypeWarning: Columns (15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   data2 = pd.read_csv('../dataset/01_raw/2021_2024_crime_data.csv')

# %%
# get column name for both datasets and print
print(data1.columns), print(data2.columns)
# Out:
# Index(['IDCol', 'Report Number', 'Report Date', 'Day Occurred', 'Day Number',
#        'Occur Date', 'Occur Time', 'Possible Date', 'Possible Time', 'Beat',
#        'Zone', 'Location', 'Apartment Number', 'Crime Type', 'NIBRS Code',
#        'Neighborhood', 'NPU', 'Longitude', 'Latitude', 'ObjectId', 'x', 'y'],
#       dtype='object')
# Index(['OBJECTID', 'Report Number', 'Report Date', 'Offense Start Date',
#        'Offense End Date', 'Day of the week', 'Day Number', 'Zone', 'Beat',
#        'Location', 'Location Type', 'NIBRS Code', 'NIBRS Code Name',
#        'Crime Against', 'Was a firearm involved?', 'Press Release',
#        'Social Media', 'Watch', 'Longitude', 'Latitude', 'Neighborhood', 'NPU',
#        'Council District', 'UCR Grouping', 'Victim Count', 'GlobalID', 'x',
#        'y'],
#       dtype='object')
# (None, None)

# %%
data1.head()
# Out:
#     IDCol  Report Number             Report Date Day Occurred  Day Number  \
# 0  320197      203581105  12/23/2020 12:00:00 AM    Wednesday           4
# 1  320198      203581144  12/23/2020 12:00:00 AM    Wednesday           4
# 2  320199      203581174  12/23/2020 12:00:00 AM     Saturday           7
# 3  320200      203581238  12/23/2020 12:00:00 AM    Wednesday           4
# 4  320201      203581247  12/23/2020 12:00:00 AM    Wednesday           4
#
#    Occur Date Occur Time Possible Date Possible Time  Beat  ...  \
# 0  12/23/2020      10:00    12/23/2020         16:45   410  ...
# 1  12/23/2020      17:16    12/23/2020         17:30   505  ...
# 2  12/19/2020      21:50    12/19/2020         22:30   211  ...
# 3  12/23/2020      18:05    12/23/2020         18:09   206  ...
# 4  12/23/2020      18:12           NaN           NaN   204  ...
#
#    Apartment Number            Crime Type NIBRS Code       Neighborhood NPU  \
# 0               NaN              BURGLARY        220   Campbellton Road   R
# 1               NaN  LARCENY-FROM VEHICLE        23F            Midtown   E
# 2               NaN  LARCENY-FROM VEHICLE        23F  Lindbergh/Morosgo   B
# 3               NaN            AUTO THEFT        240   Buckhead Village   B
# 4               NaN   LARCENY-NON VEHICLE        23C      Berkeley Park   D
#
#    Longitude   Latitude  ObjectId             x             y
# 0 -84.466012  33.702732         1 -9.402713e+06  3.988956e+06
# 1 -84.387771  33.774764         2 -9.394004e+06  3.998598e+06
# 2 -84.366938  33.819892         3 -9.391685e+06  4.004643e+06
# 3 -84.376506  33.837935         4 -9.392750e+06  4.007061e+06
# 4 -84.412846  33.804230         5 -9.396795e+06  4.002545e+06
#
# [5 rows x 22 columns]

# %%
data2.head()
# Out:
#    OBJECTID  Report Number            Report Date     Offense Start Date  \
# 0         1       21365171  12/31/2021 8:20:15 AM  12/31/2021 7:15:00 AM
# 1         2       21791668  6/29/2021 12:58:09 AM   6/28/2021 1:17:00 AM
# 2         3       22041413   2/14/2022 8:26:21 PM   1/25/2022 1:50:00 PM
# 3         4      193390123  6/24/2021 10:14:31 AM   12/5/2019 6:14:00 AM
# 4         5      202771329   8/19/2021 9:53:50 PM   10/3/2020 8:29:00 PM
#
#         Offense End Date Day of the week  Day Number  Zone Beat  \
# 0  12/31/2021 7:45:00 AM          Friday           6     6  604
# 1  6/29/2021 12:00:00 AM          Sunday           1     1  102
# 2   1/25/2022 2:15:00 PM         Tuesday           3     3  304
# 3   12/5/2019 6:40:00 AM        Thursday           5     2  211
# 4   10/3/2020 8:29:00 PM        Saturday           7     1  109
#
#                   Location  ...  Longitude   Latitude       Neighborhood NPU  \
# 0         111 BOULEVARD NE  ... -84.371743  33.757320    Old Fourth Ward   M
# 1  870 MAYSON TURNER RD NW  ... -84.416631  33.755768          Vine City   L
# 2         1192 PRYOR RD SW  ... -84.392803  33.722882        Peoplestown   V
# 3        I-85 S / GA-400 S  ... -84.361660  33.819430  Lindbergh/Morosgo   B
# 4       665 S GRAND AVE NW  ... -84.462521  33.773181        Center Hill   J
#
#   Council District UCR Grouping Victim Count  \
# 0              2.0      Part II          NaN
# 1              3.0       Part I          NaN
# 2             12.0      Part II          1.0
# 3              6.0      Part II          NaN
# 4              9.0       Part I          1.0
#
#                                GlobalID          x          y
# 0  7e30cbbb-4392-47ba-8311-b1ad817105e9 -84.371743  33.757320
# 1  104a1262-ef8a-4478-b776-1594a7206307 -84.416631  33.755768
# 2  5784d36f-0839-4795-9d8b-370e59eb72b0 -84.392803  33.722882
# 3  6217e790-ded9-421c-9ac1-eb31f53f0894 -84.361660  33.819430
# 4  44add9cf-98ce-4910-8884-ab3c9b3fbaf7 -84.462521  33.773181
#
# [5 rows x 28 columns]

# %% [markdown]
# # Merge the two datasets

# %%
#drop offense End Date column from data2
data2 = data2.drop('Offense End Date', axis=1)
data2.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 2
#       1 #drop offense End Date column from data2
# ----> 2 data2 = data2.drop('Offense End Date', axis=1)
#       3 data2.head()
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:7000, in Index.drop(self, labels, errors)
#    6998 if mask.any():
#    6999     if errors != "ignore":
# -> 7000         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7001     indexer = indexer[~mask]
#    7002 return self.delete(indexer)
#
# KeyError: "['Offense End Date'] not found in axis"

# %%
data2.head()
# Out:
#    OBJECTID  Report Number            Report Date     Offense Start Date  \
# 0         1       21365171  12/31/2021 8:20:15 AM  12/31/2021 7:15:00 AM
# 1         2       21791668  6/29/2021 12:58:09 AM   6/28/2021 1:17:00 AM
# 2         3       22041413   2/14/2022 8:26:21 PM   1/25/2022 1:50:00 PM
# 3         4      193390123  6/24/2021 10:14:31 AM   12/5/2019 6:14:00 AM
# 4         5      202771329   8/19/2021 9:53:50 PM   10/3/2020 8:29:00 PM
#
#   Day of the week  Day Number  Zone Beat                 Location  \
# 0          Friday           6     6  604         111 BOULEVARD NE
# 1          Sunday           1     1  102  870 MAYSON TURNER RD NW
# 2         Tuesday           3     3  304         1192 PRYOR RD SW
# 3        Thursday           5     2  211        I-85 S / GA-400 S
# 4        Saturday           7     1  109       665 S GRAND AVE NW
#
#                             Location Type  ...  Longitude   Latitude  \
# 0                    Service/ Gas Station  ... -84.371743  33.757320
# 1     Residence/ Home / Apartment / Condo  ... -84.416631  33.755768
# 2                    Service/ Gas Station  ... -84.392803  33.722882
# 3  Highway/ Road/ Alley/ Street/ Sidewalk  ... -84.361660  33.819430
# 4                           Other/Unknown  ... -84.462521  33.773181
#
#         Neighborhood NPU Council District UCR Grouping Victim Count  \
# 0    Old Fourth Ward   M              2.0      Part II          NaN
# 1          Vine City   L              3.0       Part I          NaN
# 2        Peoplestown   V             12.0      Part II          1.0
# 3  Lindbergh/Morosgo   B              6.0      Part II          NaN
# 4        Center Hill   J              9.0       Part I          1.0
#
#                                GlobalID          x          y
# 0  7e30cbbb-4392-47ba-8311-b1ad817105e9 -84.371743  33.757320
# 1  104a1262-ef8a-4478-b776-1594a7206307 -84.416631  33.755768
# 2  5784d36f-0839-4795-9d8b-370e59eb72b0 -84.392803  33.722882
# 3  6217e790-ded9-421c-9ac1-eb31f53f0894 -84.361660  33.819430
# 4  44add9cf-98ce-4910-8884-ab3c9b3fbaf7 -84.462521  33.773181
#
# [5 rows x 27 columns]

# %%
#check how many unique vales in Longtiude and Latitude columns

# %%
#check the data types of the columns
data2.dtypes
# Out:
# OBJECTID                     int64
# Report Number                int64
# Report Date                 object
# Offense Start Date          object
# Day of the week             object
# Day Number                   int64
# Zone                         int64
# Beat                        object
# Location                    object
# Location Type               object
# NIBRS Code                  object
# NIBRS Code Name             object
# Crime Against               object
# Was a firearm involved?     object
# Press Release               object
# Social Media                object
# Watch                       object
# Longitude                  float64
# Latitude                   float64
# Neighborhood                object
# NPU                         object
# Council District           float64
# UCR Grouping                object
# Victim Count               float64
# GlobalID                    object
# x                          float64
# y                          float64
# dtype: object

# %%
data_test = data2.copy()

# %%
# in data1 we have a column named 'Offense Start Date' that is has input format ex. '1/1/2009 0:00 AM'. We want to split this column into two columns one for Occur Date and one for Occur Time. In occur date place the '1/1/2009' and in occur time place '0:00 AM'
data_test[['Occur Date', 'Occur Time']] = data_test['Offense Start Date'].str.split(' ', 1, expand=True)
data_test.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 # in data1 we have a column named 'Offense Start Date' that is has input format ex. '1/1/2009 0:00 AM'. We want to split this column into two columns one for Occur Date and one for Occur Time. In occur date place the '1/1/2009' and in occur time place '0:00 AM'
# ----> 2 data_test[['Occur Date', 'Occur Time']] = data_test['Offense Start Date'].str.split(' ', 1, expand=True)
#       3 data_test.head()
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/strings/accessor.py:136, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     131     msg = (
#     132         f"Cannot use .str.{func_name} with values of "
#     133         f"inferred dtype '{self._inferred_dtype}'."
#     134     )
#     135     raise TypeError(msg)
# --> 136 return func(self, *args, **kwargs)
#
# TypeError: StringMethods.split() takes from 1 to 2 positional arguments but 3 positional arguments (and 1 keyword-only argument) were given

# %%
# Ensure 'Offense Start Date' is treated as a string
data2['Offense Start Date'] = data2['Offense Start Date'].astype(str)

# Now split 'Offense Start Date' into 'Occur Date' and 'Occur Time'
data2[['Occur Date', 'Occur Time']] = data2['Offense Start Date'].str.split(' ', n=1, expand=True)
data2.head()
# Out:
#    OBJECTID  Report Number            Report Date     Offense Start Date  \
# 0         1       21365171  12/31/2021 8:20:15 AM  12/31/2021 7:15:00 AM
# 1         2       21791668  6/29/2021 12:58:09 AM   6/28/2021 1:17:00 AM
# 2         3       22041413   2/14/2022 8:26:21 PM   1/25/2022 1:50:00 PM
# 3         4      193390123  6/24/2021 10:14:31 AM   12/5/2019 6:14:00 AM
# 4         5      202771329   8/19/2021 9:53:50 PM   10/3/2020 8:29:00 PM
#
#   Day of the week  Day Number  Zone Beat                 Location  \
# 0          Friday           6     6  604         111 BOULEVARD NE
# 1          Sunday           1     1  102  870 MAYSON TURNER RD NW
# 2         Tuesday           3     3  304         1192 PRYOR RD SW
# 3        Thursday           5     2  211        I-85 S / GA-400 S
# 4        Saturday           7     1  109       665 S GRAND AVE NW
#
#                             Location Type  ...       Neighborhood NPU  \
# 0                    Service/ Gas Station  ...    Old Fourth Ward   M
# 1     Residence/ Home / Apartment / Condo  ...          Vine City   L
# 2                    Service/ Gas Station  ...        Peoplestown   V
# 3  Highway/ Road/ Alley/ Street/ Sidewalk  ...  Lindbergh/Morosgo   B
# 4                           Other/Unknown  ...        Center Hill   J
#
#   Council District UCR Grouping Victim Count  \
# 0              2.0      Part II          NaN
# 1              3.0       Part I          NaN
# 2             12.0      Part II          1.0
# 3              6.0      Part II          NaN
# 4              9.0       Part I          1.0
#
#                                GlobalID          x          y  Occur Date  \
# 0  7e30cbbb-4392-47ba-8311-b1ad817105e9 -84.371743  33.757320  12/31/2021
# 1  104a1262-ef8a-4478-b776-1594a7206307 -84.416631  33.755768   6/28/2021
# 2  5784d36f-0839-4795-9d8b-370e59eb72b0 -84.392803  33.722882   1/25/2022
# 3  6217e790-ded9-421c-9ac1-eb31f53f0894 -84.361660  33.819430   12/5/2019
# 4  44add9cf-98ce-4910-8884-ab3c9b3fbaf7 -84.462521  33.773181   10/3/2020
#
#    Occur Time
# 0  7:15:00 AM
# 1  1:17:00 AM
# 2  1:50:00 PM
# 3  6:14:00 AM
# 4  8:29:00 PM
#
# [5 rows x 29 columns]
